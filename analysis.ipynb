# %%
import pandas as pd
from funpymodeling.exploratory import freq_tbl, status, profiling_num, cat_vars, num_vars
from pandas_profiling import ProfileReport
import reverse_geocoder as rg

# %%
# Cargamos los datos
data = pd.read_csv("ufo_sighting_data.csv")
# Out:
# /tmp/ipykernel_2564/3830039648.py:2: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("ufo_sighting_data.csv")

# %%
status(data)
# Out:
#                            variable  q_nan     p_nan  q_zeros  p_zeros  \
# 0                         Date_time      0  0.000000        0      0.0
# 1                              city      0  0.000000        0      0.0
# 2                    state/province   5797  0.072163        0      0.0
# 3                           country   9670  0.120375        0      0.0
# 4                         UFO_shape   1932  0.024050        0      0.0
# 5       length_of_encounter_seconds      0  0.000000        0      0.0
# 6   described_duration_of_encounter      0  0.000000        0      0.0
# 7                       description     15  0.000187        0      0.0
# 8                   date_documented      0  0.000000        0      0.0
# 9                          latitude      0  0.000000        0      0.0
# 10                        longitude      0  0.000000        0      0.0
#
#     unique     type
# 0    69586   object
# 1    19900   object
# 2       67   object
# 3        5   object
# 4       29   object
# 5      705   object
# 6     8304   object
# 7    79997   object
# 8      317   object
# 9    23292   object
# 10   19455  float64

# %%
# Veamos algunos datos
data.head(5)
# Out:
#           Date_time                  city state/province country UFO_shape  \
# 0  10/10/1949 20:30            san marcos             tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb             tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)            NaN      gb    circle
# 3  10/10/1956 21:00                  edna             tx      us    circle
# 4  10/10/1960 20:00               kaneohe             hi      us     light
#
#   length_of_encounter_seconds described_duration_of_encounter  \
# 0                        2700                      45 minutes
# 1                        7200                         1-2 hrs
# 2                          20                      20 seconds
# 3                          20                        1/2 hour
# 4                         900                      15 minutes
#
#                                          description date_documented  \
# 0  This event took place in early fall around 194...       4/27/2004
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...      12/16/2005
# 2  Green/Orange circular disc over Chester&#44 En...       1/21/2008
# 3  My older brother and twin sister were leaving ...       1/17/2004
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...       1/22/2004
#
#      latitude   longitude
# 0  29.8830556  -97.941111
# 1    29.38421  -98.581082
# 2        53.2   -2.916667
# 3  28.9783333  -96.645833
# 4  21.4180556 -157.803611

# %%
data.tail(5)
# Out:
#             Date_time       city state/province country UFO_shape  \
# 80327  9/9/2013 21:15  nashville             tn      us     light
# 80328  9/9/2013 22:00      boise             id      us    circle
# 80329  9/9/2013 22:00       napa             ca      us     other
# 80330  9/9/2013 22:20     vienna             va      us    circle
# 80331  9/9/2013 23:00     edmond             ok      us     cigar
#
#       length_of_encounter_seconds described_duration_of_encounter  \
# 80327                       600.0                      10 minutes
# 80328                      1200.0                      20 minutes
# 80329                      1200.0                            hour
# 80330                         5.0                       5 seconds
# 80331                      1020.0                      17 minutes
#
#                                              description date_documented  \
# 80327  Round from the distance/slowly changing colors...       9/30/2013
# 80328  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...       9/30/2013
# 80329                                       Napa UFO&#44       9/30/2013
# 80330  Saw a five gold lit cicular craft moving fastl...       9/30/2013
# 80331  2 witnesses 2  miles apart&#44 Red &amp; White...       9/30/2013
#
#         latitude   longitude
# 80327  36.165833  -86.784444
# 80328  43.613611 -116.202500
# 80329  38.297222 -122.284444
# 80330  38.901111  -77.265556
# 80331  35.652778  -97.477778
